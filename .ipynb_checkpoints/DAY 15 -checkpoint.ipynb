# %%
latte = 2.50
espresso = 1.50 
cappucino = 3.0


def bad_boy():
    same = input("What would you like? (espresso/latte/cappucino): ")
    return same 


meta = {'cappucino':
   {"water": 250,
   "coffe": 24,
   "milk" : 100,
   "Money": -3.00},
     'espresso' :
    {"water" : 50, 
    "coffe" : 18,
    "Money" : -1.50},
    'latte' :
    {"water" : 200,
    "coffe" : 24,
    "milk"  : 150,
    "Money" : -2.50},
    'home' :
    {"water" : 300,
    "coffe" : 100,
    "milk"  : 200,
    "Money" : 0 }}

child = True 
while child :
        user = bad_boy()
        if user == 'report':
            print('\n'.join("{}: {}".format(k, v) for k, v in meta['home'].items()))


        if user == "espresso" or "latte" or "cappucino" : 
            for key in meta['home']:
                 meta['home'][key] = (meta['home'][key]- meta['latte'][key])
        
                 if meta['home'][key] <= 0:
                     print("Insufficient resources")
                     break
            continue
#                  else :
#                      print(meta)
                         
            
            
#             for key in meta:
#                 home()
#             ans_1 = meta['home'].items() - meta[user].items()
            #now = dict(ans_1)
            #for key in now.keys():
                                      
                #if now[key] <= 0 :
#                 if meta['home'][key] <=0:
#                     print("Insufficient resources")
#                     continue
#                 else :
                        #print(ans_1)
                        
#                         meta["home"] = now
        if user == "espresso" or "latte" or "cappucino" :

            print("Please insert coins.")
            qtr = int(input("How many quaters ?:"))
            dms = int(input("How many dimes ?:"))
            nckls = int(input("How many nickes ?:"))
            pens = int(input("How many pennies"))
        else :
            print("Desire request does not exist")
            continue

        user_money = qtr*0.25 + dms*0.10 + nckls*0.05 + pens*0.01



        dict_1 = {"latte":2.50,"espresso":1.50,"cappucino":3.00}


        #for key in dict_1 : 
        if user_money > dict_1[user]:
                change = user_money - dict_1[user]
                g = float("{:.2f}".format(change))
                print(f"Here is your change : ${g}")
                print(f"""Here is your {user}  ☕️ , enjoy !""")
                continue
        if user_money < dict_1[key]:
                print("Sorry that's not enough money. Money Refunded.")
# Out:
# What would you like? (espresso/latte/cappucino): espresso
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-e7de96b9da12> in <module>
#      31 child = True
#      32 while child :
# ---> 33         user = bad_boy()
#      34         if user == 'report':
#      35             print('\n'.join("{}: {}".format(k, v) for k, v in meta['home'].items()))
#
# <ipython-input-18-e7de96b9da12> in bad_boy()
#       5
#       6 def bad_boy():
# ----> 7     same = input("What would you like? (espresso/latte/cappucino): ")
#       8     return same
#       9
#
# ~\anaconda3new\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
# ...

# %%
ans_1

# %%
meta['home'].items() + meta[user].items()

# %%
A = {'10':1, '11':1, '12':1, '10':2, '11':2, '11':3}
B = {'11':1, '11':2}
A.items() - B.items()

# %%
for key in meta['home']:
        print(type(meta['home'][key]- meta['latte'][key]))

# %%
type(ans_1)

# %%
if meta['home'][key] <= 0:
    print('')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-de96462f1b8d> in <module>
# ----> 1 if meta['home'][key] <= 0:
#       2     print('hello')
#
# NameError: name 'meta' is not defined

# %%
latte = 2.50
espresso = 1.50 
cappucino = 3.0


def bad_boy():
    same = input("What would you like? (espresso/latte/cappucino): ")
    return same 
def report():
        if user == 'report':
            print('\n'.join("{}: {}".format(k, v) for k, v in meta['home'].items()))
            return False

def resource():
    if user == "espresso" or "latte" or "cappucino" : 
        for key in meta['home']:
            new_resource = (meta['home'][key]- meta[user][key])
            if new_resource <= 0:
                print("Insufficient resources")
                return False
            else :
                meta['home'][key] = new_resource 
        
def insert():
    if user == "espresso" or "latte" or "cappucino" :

        print("Please insert coins.")
        qtr = int(input("How many quaters ?:"))
        dms = int(input("How many dimes ?:"))
        nckls = int(input("How many nickes ?:"))
        pens = int(input("How many pennies"))
    else :
        print("Desire request does not exist")
    user_moni = qtr*0.25 + dms*0.10 + nckls*0.05 + pens*0.01
    return user_moni 


def final():
    dict_1 = {"latte":2.50,"espresso":1.50,"cappucino":3.00}
    if user_money > dict_1[user]:
        change = user_money - dict_1[user]
        g = float("{:.2f}".format(change))
        print(f"Here is your change : ${g}")
        print(f"""Here is your {user}  ☕️ , enjoy !""")
        return True
    if user_money < dict_1[key]:
        print("Sorry that's not enough money. Money Refunded.")
        return False 
        


meta = {'cappucino':
   {"water": 250,
   "coffe": 24,
   "milk" : 100,
   "Money": -3.00},
     'espresso' :
    {"water" : 50, 
    "coffe" : 18,
     "milk"  : 0,
    "Money" : -1.50},
    'latte' :
    {"water" : 200,
    "coffe" : 24,
    "milk"  : 150,
    "Money" : -2.50},
    'home' :
    {"water" : 300,
    "coffe" : 100,
    "milk"  : 200,
    "Money" : 0 }}

child = True 
while child :
        user = bad_boy()
        if report() == False:
            continue
        if resource() == False:
            continue
        user_money = insert()
        if final() == False:
            continue
# Out:
# What would you like? (espresso/latte/cappucino): espresso
# Please insert coins.
# How many quaters ?:12
# How many dimes ?:12
# How many nickes ?:12
# How many pennies12
# Here is your change : $3.42
# Here is your espresso  ☕️ , enjoy !
# What would you like? (espresso/latte/cappucino): espresso
# Please insert coins.
# How many quaters ?:12
# How many dimes ?:12
# How many nickes ?:12
# How many pennies12
# Here is your change : $3.42
# Here is your espresso  ☕️ , enjoy !
# What would you like? (espresso/latte/cappucino): report
# water: 200
# coffe: 64
# milk: 200
# Money: 3.0
# What would you like? (espresso/latte/cappucino): latte
# Insufficient resources
# What would you like? (espresso/latte/cappucino): report
# water: 200
# coffe: 64
# milk: 200
# Money: 3.0

# %%
i look up and i see my goal 
how far off i am 
i'm not moving but my feet are moving 
is there something wrong 
what's the problem
i'm moving but my goal is still at the same position 
it's still far far away 
let me check again 
my feet are still moving 
then what is the problem .
wait ?
Let me take a look behind me to see if i'm the only one with the problem 
no one in sight but one thing is certain
i'm not where i started 
i'm moving 
i must keep going 

Sometimes we just need to take a look back to see our growth,it might be slow but you are surely growing .
