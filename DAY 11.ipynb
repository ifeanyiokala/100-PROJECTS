# %% [markdown]
# # BLACKJACK

# %%
import random
from blackjack import logo
from IPython.display import clear_output


print(logo)


def game_cards():
    cards = [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10]
    user = random.sample(cards,2)
    computer = random.sample(cards,2)
    print(user)
    print(computer)

    sum_user = sum(user)
    sum_computer = sum(computer)

    if 11 in user and 10 in user :
        print("User has a blackjack")
        print("User Wins")
    elif 11 in computer and 10 in computer :
        print("Computer has a blackjack")
        print("Computer Wins, You Lose !")
    elif sum_user > 21 :
        if 11 in sum_user :
            new_user = user.replace(11,1)
            sum_new_user = sum(new_user)
        if sum_new_user > 21:
            print("Computer wins,You lose")
        else:
            print("Computer wins,You lose")
    else :
        draw = input("Would you want to draw another card ?, 'Yes' or 'No' ")

    if draw == 'Yes':
        third_user = random.choice(cards)
        user.append(third_user)
        print(user)
    sum_user = sum(user)
    if sum_user > 21 :
        print('Computer wins,you lose')
    if  sum_computer < 17 :
        third_computer = random.choice(cards)
        computer.append(third_computer) 
    sum_comp = sum(computer)
    if sum_comp > 21 :
        print('You win,computer lost')
    elif  21 >= sum_user > sum_comp :
        print('You Win,well done !')
    elif 21 >= sum_user < sum_comp :
        print('Computer Wins,Sad')
    elif sum_user == sum_comp:
        print("It's a Draw")

    else:
        if sum_computer < 17 :
            third_computer = random.choice(cards)
            computer.append(third_computer) 
            sum_comp = sum(computer)
        if sum_comp > 21 :
            print('You win,computer lost')
        elif  21 >= sum_user > sum_comp :
            print('You Win,well done !')
        elif 21 >= sum_user < sum_comp :
            print('Computer Wins,Sad')
        elif sum_user == sum_comp:
            print("It's a Draw")


game_cards()


Path = True

while Path :  
    end = input("Do you want to restart the game, Yes or No : ")
    if end == 'Yes':
        clear_output(wait=False)
        game_cards()
    else :
        Path = False
# Out:
# .------.            _     _            _    _            _
# |A_  _ |.          | |   | |          | |  (_)          | |
# |( \/ ).-----.     | |__ | | __ _  ___| | ___  __ _  ___| | __
# | \  /|K /\  |     | '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
# |  \/ | /  \ |     | |_) | | (_| | (__|   <| | (_| | (__|   <
# `-----| \  / |     |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\
#       |  \/ K|                            _/ |
#       `------'                           |__/
#
# [10, 6]
# [8, 3]
# Would you want to draw another card ?, 'Yes' or 'No' Yes
# [10, 6, 11]
# Computer wins,you lose
# You win,computer lost
# Do you want to restart the game, Yes or No : No
